# %%
import _resume_eval_import_helper

# %%
import pandas as pd

# %%
df = pd.read_csv("output/two_stage_evaluation_results_detailed.csv")

df_yes = df[df["suitability"] == "yes"].reset_index(drop=True)
df_potential = df[df["suitability"] == "kiv"].reset_index(drop=True)

del df

# %%
df_yes.sort_values(["job_id", "recalibrated_overall_score"])
# Out:
#                                  job_id                                 cv_id  \
# 7  40705682-6752-41f0-8a6d-b01b9d7b1746  af844c8b-de2a-47ff-9b7d-4466af8826c2
# 2  5535b3b6-f919-4e04-bb23-5eb63436941f  86cab53a-a56e-46a5-a788-ed9ce55b6879
# 0  5535b3b6-f919-4e04-bb23-5eb63436941f  b2787176-a5e0-45be-affa-6f955925ddc6
# 3  5535b3b6-f919-4e04-bb23-5eb63436941f  bd1a92a0-5f5a-4b88-b3e2-606f9c10fbd1
# 9  5535b3b6-f919-4e04-bb23-5eb63436941f  a475d257-1db0-4073-a2e7-c102b5440dc5
# 4  5535b3b6-f919-4e04-bb23-5eb63436941f  954ab12a-1f45-46fb-b96c-4bb8d8f6d59f
# 5  5535b3b6-f919-4e04-bb23-5eb63436941f  8ebd43dc-8000-4c15-baad-1868b349ea56
# 6  769c3093-32c5-4122-ae8f-d4f99a22354a  39b5761c-b124-4c97-86a1-9f3ef0d5b77c
# 8  b04cc5ce-b93e-427e-9439-0965e64779ff  797436e9-bd0e-42f1-85fe-1fd288a575fc
# 1  ca0539ba-835b-48fb-bed0-705d6668c372  21124c0b-1510-481b-b006-7bf6bebec2a0
#
#   model_name  original_technical_skills  original_soft_skills  \
# ...

# %%
df_yes[df_yes["job_id"] == "40705682-6752-41f0-8a6d-b01b9d7b1746"].T
# Out:
#                                                                                7
# job_id                                      40705682-6752-41f0-8a6d-b01b9d7b1746
# cv_id                                       af844c8b-de2a-47ff-9b7d-4466af8826c2
# model_name                                                                  groq
# original_technical_skills                                                     80
# original_soft_skills                                                          80
# original_experience                                                           70
# original_education                                                           100
# recalibrated_technical_skills                                                 85
# recalibrated_soft_skills                                                      85
# recalibrated_experience                                                       75
# recalibrated_education                                                       100
# ...

# %%
print(df_yes[df_yes["job_id"] == "40705682-6752-41f0-8a6d-b01b9d7b1746"]["job_description"].values[0])
# Out:
# Job Summary -
# Lumenci is a legal tech startup founded by group of IIT alumni in US. Lumenci’s mission is to transform the legal and intellectual property industry in US & Europe with groundbreaking products and services. We are currently looking to build an exceptionally strong technical team in Gurgaon, India, to help us deliver high quality products and services to our clients.
# The Role
#  Design and develop software tools related to tracking, implementing, managing and presenting data.
#  Researching, designing, implementing and managing software programs
#  Testing and evaluating new programs
#  Identifying areas for modification in existing programs and subsequently developing these modifications
#  Writing and implementing efficient code
#  Determining operational practicality
#  Develop software tools which will automate various manual processes.
#  Develop and design dashboard and UI related tools.
# ...

# %%
print(df_yes[df_yes["job_id"] == "40705682-6752-41f0-8a6d-b01b9d7b1746"]["cv"].values[0])
# Out:
# Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, Nave Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details
# Data Science Assurance Associate
# Data Science Assurance Associate - Ernst & Young LLP
# Skill Details
# JAVASCRIPT- Exprience - 24 months
# jQuery- Exprience - 24 months
# Python- Exprience - 24 monthsCompany Details
# company - Ernst & Young LLP
# ...

# %%
print(df_yes[df_yes["job_id"] == "40705682-6752-41f0-8a6d-b01b9d7b1746"]["concerns"].values[0])
# Out:
# The candidate lacks experience with Django, which is an essential skill for the job. However, their overall skills and experience make them a strong fit for the role.

# %%
# 5535b3b6-f919-4e04-bb23-5eb63436941f

# %%
df_yes[df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f"].T
# Out:
#                                                                                0  \
# job_id                                      5535b3b6-f919-4e04-bb23-5eb63436941f
# cv_id                                       b2787176-a5e0-45be-affa-6f955925ddc6
# model_name                                                                  groq
# original_technical_skills                                                     80
# original_soft_skills                                                          60
# original_experience                                                           80
# original_education                                                           100
# recalibrated_technical_skills                                                 85
# recalibrated_soft_skills                                                      65
# recalibrated_experience                                                       85
# recalibrated_education                                                       100
# ...

# %%
from pprint import pprint

pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "8ebd43dc-8000-4c15-baad-1868b349ea56")]["cv"].values[0])
# Out:
# ('Education Details \n'
#  'May 2011 to May 2014 Bachelor of science Information technology Mumbai, '
#  'Maharashtra Mumbai university\n'
#  'Oracle DBA \n'
#  'Oracle database administrator\n'
#  'Skill Details \n'
#  'Installation of Oracle on RH Linux & Windows. Creating/Managing user '
#  'profiles and analyzing their privileges and tablespace quotas Backup of '
#  'database Logical and Physical procedures. Recovery of database in case of '
#  'database crash, disk/media failure, etc. Standard DBA functions like space '
#  'management, Rollback segments, Extents. Database Management and Monitoring '
#  'the database. Willing to learn new things. Being a constructive team member, '
#  'contributing practically to the success of the team.- Exprience - 48 '
#  'monthsCompany Details \n'
#  'company - Accelya kale solutions ltd\n'
#  'description - Database Administrator working in 24*7 support environment '
#  'maintaining Databases running on Oracle 11g, 12c.\n'
# ...

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "8ebd43dc-8000-4c15-baad-1868b349ea56")]["job_description"].values[0])
# Out:
# ('mandatory skill rdbms - database development job description key skill '
#  'required job rdbms - database development-l3 mandatory minimum work '
#  'experience:7 - 10 year 7-10 year experience good background experience data '
#  'analysis experience gathering analyzing system requirement able formulate '
#  'quick data analysis agile environment contribute design implementation '
#  'perspective business need strong experience source target mapping excellent '
#  'communication skill exposure client interaction day day basis excellent '
#  'leadership skill drive agile based project development good knowledge sql '
#  'oracle good understanding data model database design principle experience '
#  'agile development process ba/da experience requirement design documentation '
#  'role & responsibility minimum experience required 3-5 year mandatory skill '
#  'rdbms - database development db modeling unix shell scripting perl '
# ...

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "8ebd43dc-8000-4c15-baad-1868b349ea56")]["concerns"].values[0])
# Out:
# ('The candidate lacks experience in DB modeling, Unix shell scripting, and '
#  'Perl programming, which are essential skills for the job.')

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "8ebd43dc-8000-4c15-baad-1868b349ea56")]["strengths"].values[0])
# Out:
# ('The candidate has strong technical skills in Oracle DBA, database '
#  'administration, and backup and recovery. They also have excellent experience '
#  'in managing databases and performing maintenance activities.')

# %% [markdown]
# ## case II

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "954ab12a-1f45-46fb-b96c-4bb8d8f6d59f")]["cv"].values[0])
# Out:
# ('Education Details \n'
#  'SAP Technical Architect \n'
#  'SAP Technical Consultant -  (ALE/IDOC/oDATA/Fiori/S4HANA/EWM/APO/Retail)\n'
#  'Skill Details \n'
#  'SAP ABAP- Exprience - 120 months\n'
#  'SAP ABAP ( ALE / IDOC / EDI )- Exprience - 96 months\n'
#  'SAP Netweaver Gateway / oData / Fiori- Exprience - 24 months\n'
#  'SAP Techno Functional- Exprience - 36 months\n'
#  'SAP ABAP ( IS-Retail / APO / IS-Auto / EWM)- Exprience - 36 months\n'
#  'SAP Techno-functional- Exprience - 48 months\n'
#  'SAP SD- Exprience - 36 months\n'
#  'NetWeaver Gateway (oDATA, Fiori)- Exprience - 24 months\n'
#  'SAP S/4HANA (new features Extensibility, Embedded Analytics)- Exprience - 12 '
#  'monthsCompany Details \n'
#  'company - \n'
#  'description - 13+ years of work experience in SAP which includes roles '
#  'varies from developer to subject matter expert\n'
#  ' Strong project experience in implementation, upgrade, application '
#  'development and maintenance\n'
# ...

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "954ab12a-1f45-46fb-b96c-4bb8d8f6d59f")]["strengths"].values[0])
# Out:
# ('The candidate has extensive experience in SAP ABAP and has worked on '
#  'multiple projects, demonstrating strong technical skills. The candidate also '
#  'has excellent communication skills, leadership skills, and experience in '
#  'client interaction.')

# %%
pprint(df_yes[(df_yes["job_id"] == "5535b3b6-f919-4e04-bb23-5eb63436941f") & (df_yes["cv_id"] == "954ab12a-1f45-46fb-b96c-4bb8d8f6d59f")]["concerns"].values[0])
# Out:
# ('The candidate lacks experience in RDBMS, Database development, Unix shell '
#  'scripting, Perl programming, and DB modeling, which are essential skills for '
#  'the job.')
