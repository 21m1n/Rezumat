# %%
import _resume_eval_import_helper

# %%
import json 
from pathlib import Path
from tqdm.auto import tqdm

import pandas as pd

# %% [markdown]
# # consolidate results

# %% [markdown]
# ## GPT-4o

# %%
folder_path = Path("output_20240831_1144")
json_files = list(folder_path.glob("*.json"))

gpt4o_verdict = {}

for file in tqdm(json_files, desc="Processing files"):
  jd_id, cv_id = file.stem.split("_")[:2]
  with open(file, "r") as f:
    data = json.load(f)
    try:
      verdict = data["assessment"]["suitability"]
    except:
      verdict = None
    gpt4o_verdict[(jd_id, cv_id)] = verdict
    
    
gpt4o_verdict = pd.DataFrame(gpt4o_verdict, index=["suitability"]).T.reset_index().rename(columns={"level_0": "job_id", "level_1": "cv_id", "suitability": "gpt4o"})
# Out:
# Processing files:   0%|          | 0/704 [00:00<?, ?it/s]

# %% [markdown]
# ## llama3 70b

# %%
folder_path = Path("output_20240831_0124")
json_files = list(folder_path.glob("*.json"))

llama3_70b_verdict = {}

for file in tqdm(json_files, desc="Processing files"):
  jd_id, cv_id = file.stem.split("_")[:2]
  with open(file, "r") as f:
    data = json.load(f)
    verdict = data["assessment"]["suitability"]
    
    llama3_70b_verdict[(jd_id, cv_id)] = verdict

llama3_70b_verdict = pd.DataFrame(llama3_70b_verdict, index=["suitability"]).T.reset_index().rename(columns={"level_0": "job_id", "level_1": "cv_id", "suitability": "llama3_70b"})
# Out:
# Processing files:   0%|          | 0/705 [00:00<?, ?it/s]

# %% [markdown]
# ## previous results

# %%
import pandas as pd
from tqdm.auto import tqdm

output_dir = Path("output_20240830_0136")

df = pd.DataFrame()
csv_files = output_dir.glob("*.csv")

for file in tqdm(csv_files, desc="Processing files"):
  
  job_id, cv_id = file.name.split("_")[:2]
  df_ = pd.read_csv(file)
  df_["job_id"] = job_id
  df_["cv_id"] = cv_id[:-4]
  df = pd.concat([df, df_], axis=0)
# Out:
# Processing files: 0it [00:00, ?it/s]

# %%
df_ = df.pivot_table(index=["job_id", "cv_id"], columns="Model", values="suitability", aggfunc="first").reset_index()

# %%
df_.columns, llama3_70b_verdict.columns, gpt4o_verdict.columns
# Out:
# (Index(['job_id', 'cv_id', 'anthropic', 'gpt', 'llama3'], dtype='object', name='Model'),
#  Index(['job_id', 'cv_id', 'llama3_70b'], dtype='object'),
#  Index(['job_id', 'cv_id', 'gpt4o'], dtype='object'))

# %%
df_.shape, llama3_70b_verdict.shape, gpt4o_verdict.shape
# Out:
# ((692, 5), (705, 3), (704, 3))

# %%
final_verdict = pd.merge(llama3_70b_verdict, gpt4o_verdict, on=["job_id", "cv_id"], how="left")
final_verdict = pd.merge(final_verdict, df_, on=["job_id", "cv_id"], how="left")

final_verdict.sort_values(by=["job_id", "cv_id"], inplace=True)
final_verdict.to_csv("output/final_verdict.csv", index=False)

# %% [markdown]
# ## add job description and cv

# %%
folder_path = Path("output")

job_pool = pd.read_csv("output/filtered_job_description.csv")
talent_pool = pd.read_csv("output/filtered_talent_pool.csv")

job_pool.rename(columns={"Job ID": "job_id", "Job Description": "job_description", "Job Title": "job_title"}, inplace=True)
talent_pool.rename(columns={"ID": "cv_id", "Resume": "cv", "Category": "cv_category"}, inplace=True)

# %%
final_verdict = pd.merge(job_pool, final_verdict, on="job_id", how="left")
final_verdict = pd.merge(talent_pool, final_verdict, on="cv_id", how="left")
final_verdict.to_csv("output/final_verdict_with_jd_cv.csv", index=False)

# %%
final_verdict.head(3).T
# Out:
#                                                                  0  \
# cv_category                                                 Hadoop
# cv               Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# cv_id                         c48924db-2f11-40a7-96cf-152ac401e14c
# job_title                                        Flutter Developer
# job_description  Job Title: Flutter Developer\nLocation: Malapp...
# job_id                        fb3ec592-b093-46ca-8dfd-de3e164b49ac
# llama3_70b                                                      no
# gpt4o                                                           no
# anthropic                                                      kiv
# gpt                                                            kiv
# llama3                                                          no
#
#                                                                  1  \
# cv_category                                                 Hadoop
# cv               Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# cv_id                         c48924db-2f11-40a7-96cf-152ac401e14c
# job_title                                         Django Developer
# job_description  Job Responsibilities:\n6+ years of Hands-on ex...
# job_id                        7e259146-d9df-411e-8550-2fef51dc7bc9
# llama3_70b                                                      no
# gpt4o                                                           no
# anthropic                                                      kiv
# gpt                                                             no
# llama3                                                         NaN
#
#                                                                  2
# cv_category                                                 Hadoop
# cv               Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# cv_id                         c48924db-2f11-40a7-96cf-152ac401e14c
# job_title                                         Machine Learning
# job_description  About the role\nIn this role you will:\nBe wor...
# job_id                        31fde0c0-866a-48f9-b399-aad6f9c472a8
# llama3_70b                                                      no
# gpt4o                                                           no
# anthropic                                                       no
# gpt                                                             no
# llama3                                                         NaN

# %%
del job_pool, talent_pool, df_, llama3_70b_verdict, gpt4o_verdict

# %% [markdown]
# # EDA of results

# %%
print(f"total {final_verdict['job_id'].nunique()} job descriptions")

print("per jd, we have ~40 applications")
final_verdict.groupby(["job_id"])["cv_id"].nunique()
# Out:
# total 15 job descriptions
# per jd, we have ~40 applications
# job_id
# 2f1247bd-4c98-4357-8b8b-ac52ee8698b2    47
# 31fde0c0-866a-48f9-b399-aad6f9c472a8    47
# 40705682-6752-41f0-8a6d-b01b9d7b1746    47
# 5535b3b6-f919-4e04-bb23-5eb63436941f    47
# 66c5e115-cf87-4917-9cff-c2d72156cff6    47
# 769c3093-32c5-4122-ae8f-d4f99a22354a    47
# 7e259146-d9df-411e-8550-2fef51dc7bc9    47
# 83d835b5-ab57-4044-ace8-a5d8ffc0e254    47
# 8f52ff7e-1929-49d9-86d3-052e98986b34    47
# 90c1ee72-9c8d-46d4-a671-cb7cba7f75df    47
# 91793843-4ca9-4eb6-9d84-8c59a3d19812    47
# b04cc5ce-b93e-427e-9439-0965e64779ff    47
# ca0539ba-835b-48fb-bed0-705d6668c372    47
# dcb1513a-460d-46f7-81b1-23294a691bfd    47
# fb3ec592-b093-46ca-8dfd-de3e164b49ac    47
# Name: cv_id, dtype: int64

# %% [markdown]
# ## distribution of suitability

# %%
mod_list = ["llama3_70b", "gpt4o", "anthropic", "gpt", "llama3"]

for mod in mod_list:
  print(final_verdict[mod].value_counts(normalize=True))
  print()
# Out:
# llama3_70b
# no     0.617021
# kiv    0.238298
# yes    0.144681
# Name: proportion, dtype: float64
#
# gpt4o
# no     0.663818
# kiv    0.317664
# yes    0.018519
# Name: proportion, dtype: float64
#
# anthropic
# kiv    0.535714
# no     0.464286
# Name: proportion, dtype: float64
#
# gpt
# kiv    0.764110
# no     0.219971
# yes    0.015919
# Name: proportion, dtype: float64
#
# llama3
# kiv    0.813880
# no     0.164038
# yes    0.022082
# Name: proportion, dtype: float64

# %%
final_verdict.head()
# Out:
#   cv_category                                                 cv  \
# 0      Hadoop  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 1      Hadoop  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 2      Hadoop  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 3      Hadoop  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 4      Hadoop  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
#
#                                   cv_id             job_title  \
# 0  c48924db-2f11-40a7-96cf-152ac401e14c     Flutter Developer
# 1  c48924db-2f11-40a7-96cf-152ac401e14c      Django Developer
# 2  c48924db-2f11-40a7-96cf-152ac401e14c      Machine Learning
# 3  c48924db-2f11-40a7-96cf-152ac401e14c         iOS Developer
# 4  c48924db-2f11-40a7-96cf-152ac401e14c  Full Stack Developer
#
#                                      job_description  \
# 0  Job Title: Flutter Developer\nLocation: Malapp...
# 1  Job Responsibilities:\n6+ years of Hands-on ex...
# 2  About the role\nIn this role you will:\nBe wor...
# 3  Technical Skills:\nMinimum 4 years of experien...
# 4  position description demonstrates up-to-date e...
#
#                                  job_id llama3_70b gpt4o anthropic  gpt llama3
# 0  fb3ec592-b093-46ca-8dfd-de3e164b49ac         no    no       kiv  kiv     no
# 1  7e259146-d9df-411e-8550-2fef51dc7bc9         no    no       kiv   no    NaN
# 2  31fde0c0-866a-48f9-b399-aad6f9c472a8         no    no        no   no    NaN
# 3  83d835b5-ab57-4044-ace8-a5d8ffc0e254         no    no       NaN  kiv    kiv
# 4  2f1247bd-4c98-4357-8b8b-ac52ee8698b2        yes   kiv       NaN  kiv    NaN

# %% [markdown]
# ## gpt-4o vs llama3-70b

# %%
final_verdict[["llama3_70b", "gpt4o"]].value_counts(normalize=True)
# Out:
# llama3_70b  gpt4o
# no          no       0.542735
# kiv         kiv      0.126781
# yes         kiv      0.116809
# kiv         no       0.111111
# no          kiv      0.074074
# yes         yes      0.015670
#             no       0.009972
# kiv         yes      0.001425
# no          yes      0.001425
# Name: proportion, dtype: float64

# %%
disagreement = final_verdict[final_verdict["llama3_70b"] != final_verdict["gpt4o"]]
disagreement.to_csv("output/disagreement_gpt4o_llama3_70b.csv", index=False)

# %%
import gradio as gr
import pandas as pd
import json
from pathlib import Path

# Load the data
final_verdict = pd.read_csv("output/final_verdict_with_jd_cv.csv")

# Global variable to keep track of the current index
current_index = 0

def load_llama3_reasoning(job_id, cv_id):
    json_path = Path(f"output_20240831_0124/{job_id}_{cv_id}_groq.json")
    if json_path.exists():
        with open(json_path, "r") as f:
            data = json.load(f)
            return json.dumps(data, indent=2)
    return "Reasoning not available"

def load_entry(index):
    entry = final_verdict.iloc[index]
    llama3_reasoning = load_llama3_reasoning(entry['job_id'], entry['cv_id'])
    return (
        entry['job_title'],
        entry['job_description'],
        entry['cv_category'],
        entry['cv'],
        f"Anthropic: {entry['anthropic']}\nGPT: {entry['gpt']}\nLlama3: {entry['llama3_70b']}",
        llama3_reasoning
    )

def update_decision(decision):
    global current_index
    final_verdict.loc[current_index, 'user_decision'] = decision
    final_verdict.to_csv("output/final_verdict_with_user_decision.csv", index=False)
    current_index += 1
    return load_entry(current_index)

def shortlist():
    return update_decision("Shortlist")

def reject():
    return update_decision("Reject")

def kiv():
    return update_decision("KIV")

def load_first_entry():
    return load_entry(0)

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            job_title = gr.Textbox(label="Job Title")
            job_description = gr.Textbox(label="Job Description", lines=10)
        with gr.Column():
            cv_category = gr.Textbox(label="CV Category")
            cv = gr.Textbox(label="Resume (CV)", lines=10)
    
    model_verdicts = gr.Textbox(label="Model Verdicts", lines=3)
    llama3_reasoning = gr.Code(label="Llama3 Reasoning", language="json")
    
    with gr.Row():
        shortlist_btn = gr.Button("Shortlist", variant="primary")
        reject_btn = gr.Button("Reject", variant="stop")
        kiv_btn = gr.Button("KIV", variant="secondary")
    
    shortlist_btn.click(shortlist, outputs=[job_title, job_description, cv_category, cv, model_verdicts, llama3_reasoning])
    reject_btn.click(reject, outputs=[job_title, job_description, cv_category, cv, model_verdicts, llama3_reasoning])
    kiv_btn.click(kiv, outputs=[job_title, job_description, cv_category, cv, model_verdicts, llama3_reasoning])
    
    demo.load(load_first_entry, outputs=[job_title, job_description, cv_category, cv, model_verdicts, llama3_reasoning])

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
# IMPORTANT: You are using gradio version 4.19.2, however version 4.29.0 is available, please upgrade.
# --------
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# looking at the log, a number of results are missing due to parsing error (llama3) and rate limit (anthropic)

# %%
# log_file_dir = Path("output/evaluation_log.txt")

# # def extract_json(error_message):

# def process_log_file(log_file_path, output_file_path):
  
#   with open(log_file_path, "r") as file:
#     log_content = file.read()

# %%
# log_file_dir = Path("output/evaluation_log.txt")

# with open(log_file_dir, "r") as file:
#     log_content = file.read()

# %%
# import re

# error_entries = re.findall(r"ERROR - Error with llama3 for job_id:.*, cv_id:.*(?=\.)", log_content)

# uuid_pattern =  r"^[0-9a-fA-F]{8}-[0-9a-fA-F]{4}-[1-5][0-9a-fA-F]{3}-[89abAB][0-9a-fA-F]{3}-[0-9a-fA-F]{12}$"

# %%
# job_id = re.search(r'job_id: ([^,\s]+)', entry)
# cv_id = re.search(r'cv_id: ([^,\s]+)', entry)


# re.search(entry, log_content).group()
# # overall result

# %%
# error_pattern = r'^\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2} - ERROR -'
# info_pattern =r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2} - INFO -' 
# sections = re.split(error_pattern, log_content, flags=re.MULTILINE)
# sections = [item.strip() for item in sections if item.strip().startswith("Error with llama3")]
# sections = [re.split(info_pattern, sec)[0] for sec in sections]
# json_strs = [re.search(r'(\{.*\})', sec, re.DOTALL).group(1) for sec in sections]

# %%
# import json
# count = 0
# for j in tqdm(json_strs, total=len(json_strs)):
#   try:
#     json.loads(j)
#   except:
#     print(j)
#     print("-"*100)  
#     count += 1
#     break
# Out:
#   0%|          | 0/375 [00:00<?, ?it/s]
# {
#   "job_description_analysis": {
#     "technical_skills": [
#       {"Flutter": "essential"},
#       {"Android Application Development": "essential"},
#       {"Algorithms": "essential"},
#       {"Restful Web Services": "essential"},
#       {"Offline Storage": "advantageous"},
#       {"Threading": "advantageous"},
#       {"Performance Tuning": "advantageous"},
#       {"Push Notifications": "essential"},
#       {"API Integrations": "essential"}
#     ],
#     "soft_skills": [
#       "Analytical",
#       "Problem Solving",
#       "Decision Making"
#     ],
#     "required_experience": [1],
#     "education_qualifications": []
#   },
#   "resume_evaluation": {
#     "original_scores": {
#       "technical_skills": 0,
#       "soft_skills": 0,
#       "relevant_experience": 0,
#       "qualifications": 0
#     },
#     "missing_skills": [
#       {"Offline Storage": "advantageous"},
#       {"Threading": "advantageous"},
#       {"Performance Tuning": "advantageous"}
#     ]
#   },
#   "deeper_analysis": {
#     "inferred_experiences": [
#       {"Data Processing Algorithms": "similar to Offline Storage and Threading"},
#       {"System Performance Optimization": "similar to Performance Tuning"}
#     ]
#   },
#   "recalibrated_scores": {
#     "technical_skills": 60,
#     "soft_skills": 0,
#     "experience": 20,
#     "education_qualifications": 0
#   },
#   "assessment": {
#     "suitability": "kiv",
#     "strengths": [
#       {"Hadoop Ecosystem Experience"},
#       {"Data Processing and Analytics Skills"}
#     ],
#     "potential_concerns": [
#       {"Lack of Flutter and Android Application Development Experience"},
#       {"No Direct Experience with Push Notifications and API Integrations"}
#     ],
#     "missing_skills": [
#       {"Offline Storage": "advantageous"},
#       {"Threading": "advantageous"},
#       {"Performance Tuning": "advantageous"}
#     ]
#   }
# }
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # overall result

# %%
df.groupby(["Model"])["suitability"].value_counts(normalize=True)
# Out:
# Model      suitability
# anthropic  kiv            0.535714
#            no             0.464286
# gpt        kiv            0.764110
#            no             0.219971
#            yes            0.015919
# llama3     kiv            0.813880
#            no             0.164038
#            yes            0.022082
# Name: proportion, dtype: float64

# %% [markdown]
# ## does the model agree with each other?

# %%
# get the results o
model_results_comparison = df.groupby(["job_id", "cv_id"])[["Model", "suitability"]].value_counts().reset_index()

# %%
model_results_comparison.to_csv("model_results_comparison.csv", index=False)

# %%
df_ = df.pivot_table(index=["job_id", "cv_id"], columns="Model", values="suitability", aggfunc="first").reset_index()
df_["count"] = df_[["anthropic", "gpt", "llama3"]].count(axis=1)
# df_["agreement"] = (df_[["anthropic", "gpt", "llama3"]].nunique(dropna=True, axis=1) == 1) & (df_["count"] > 1)
df_["agreement"] = (df_[["anthropic", "gpt", "llama3"]].nunique(dropna=True, axis=1) == 1) 
df_.to_csv("model_results_per_jd_cv.csv", index=False)

# %%
df_[df_["count"] > 1]["agreement"].value_counts(normalize=True)
# Out:
# agreement
# True     0.71466
# False    0.28534
# Name: proportion, dtype: float64

# %%
disagreement_df = df_[(df_["count"] > 1) & (~df_["agreement"])]
disagreement_df.to_csv("disagreement_df.csv", index=False)

# %% [markdown]
# # eyeballing the disagreement

# %%
import pandas as pd 
from IPython.display import display, Markdown

job_pool = pd.read_csv("output/filtered_job_description.csv")
talent_pool = pd.read_csv("output/filtered_talent_pool.csv")

# %%
job_id = "2f1247bd-4c98-4357-8b8b-ac52ee8698b2"
cv_id = "a6f20105-1395-4f20-b1c9-139ae9f0ef42"

def get_jd_cv(job_id, cv_id):
  job = job_pool[job_pool["Job ID"] == job_id]["Job Description"].values[0]
  cv = talent_pool[talent_pool["ID"] == cv_id]["Resume"].values[0]
  
  pprint((f"**Job Description:**\n{job}"))
  print()
  pprint((f"**CV:**\n{cv}"))

get_jd_cv(job_id, cv_id)
# Out:
# ('**Job Description:**\n'
#  'position description demonstrates up-to-date expertise software engineering '
#  'applies development execution improvement action plan manages small '
#  'medium-sized complex team project model compliance company policy procedure '
#  'support company standard ethic integrity provides support implementation '
#  'business solution provides support business new existing system '
#  "troubleshoots business production issue minimum qualification bachelor 's "
#  'degree computer science related field 4 year experience building scalable '
#  'ecommerce application mobile software additional preferred qualification '
#  'company summary walmart ecommerce team rapidly innovating evolve define '
#  'future state shopping world ’ largest retailer mission help people save '
#  'money live better help brightest mind technology merchandising marketing '
#  'supply chain talent reimagining intersection digital physical shopping help '
#  'achieve mission position summary walmart lab ’ reinventing world ’ leading '
#  'retail platform leveraging unique strength deliver best customer experience '
#  'wherever customer shop imagine environment one line code one experiment one '
#  'idea ha power catapult entire industry towards smarter future better yet '
#  'imagine power could every day ’ walmart lab tech-empowered people-led ’ team '
#  '4000+ software engineer data scientist designer product manager within '
#  'walmart across world delivering innovation transform customer shop '
#  'enterprise operates technologist solve complex problem walmart building '
#  'solution impact hundred million people world ’ largest retailer')
#
# ('**CV:**\n'
#  'Skill Set Cisco Certified Network Associates (CCNA): -  Basic knowledge of '
#  'networking such as Ethernet mediums, ethernet communication, types of '
#  'Ethernet communication devices etc.  IPv4 (Subnetting, Supernetting)  Basic '
#  'configuration of Routing, Switching, Access lists, Network Address '
#  'Translation (NAT), Virtual LANs (VLANs) etc Cisco Certified Network '
#  'Associates (CCNA-Security): -  Basic security goals and need.  Different '
#  'types of attacks like access attacks, reconnaissance strategies etc.  Basic '
#  'configuration of firewalls.  Mitigation techniques such as access control '
#  'lists, private VLANs, VLAN hopping, IP source guard, DHCP snooping, '
#  'Authentication, Authorization & Accounting (AAA), IP Security (IPsec) etc. '
#  'Cisco Certified Network Professional (CCNP-Routing, Switching & MPLS): -  '
#  'Routing-Configuration and concept of EIGRP, OSPF and BGP.  Switching-Virtual '
#  'LANs (VLANs), spanning tree protocol (STP), queuing etc.  MPLS '
#  '(Multi-Protocol Label Switching) -Basic idea about working, types and modes '
#  'of MPLS, penultimate hopping in mpls etc. Cisco Certified Network '
#  'Professional Security (ASA Module): -  Knowledge of Control Plane Security, '
#  'Management Plane Security and Data Plane Security.  Knowledge of Network '
#  'Telemetary (NTP, NetFlow, Logging), NAT fundamental on ASA.  Firewall '
#  'filtering technologies, ASA modes of deployment, ASA failover, Security '
#  'context, Reputation based firewall, Identity firewall, Zone based firewall. '
#  'Projects T.E. Project: Title: -Temperature Controlled Cooling Fan Academic '
#  'Year: 2016-2017 (sem-5) Description:  This project simply senses the '
#  'temperature level and turn ON the FAN when temperature is above set limit. '
#  'This project was developed with an aim to control the temperature of devices '
#  'and reduce the damages of the devices because of heating. Title:- Automatic '
#  'Plant Watering System Academic Year: 2016-2017 (sem-6) Description:  This '
#  'project simply senses the moisture level and turn ON the water pump when '
#  'moisture is Education Details \n'
#  'January 2018 B.E Technology Mumbai, Maharashtra Mumbai university\n'
#  ' H.S.C Mahatma Gandhi High  Maharashtra State Board\n'
#  ' S.S.C. Mahatma Gandhi High  Maharashtra State Board\n'
#  '    School & Junior College\n'
#  'Network Security Enginner \n'
#  'Network Security Engineer\n'
#  'Skill Details \n'
#  'Networking- Exprience - Less than 1 year months\n'
#  'Subnetting,Supernetting- Exprience - Less than 1 year months\n'
#  'Access Lists- Exprience - Less than 1 year months\n'
#  'ACLS- Exprience - 6 months\n'
#  'Network Address Translation(NAT)- Exprience - Less than 1 year months\n'
#  'VLAN- Exprience - Less than 1 year months\n'
#  'AAA- Exprience - Less than 1 year months\n'
#  'IPSec- Exprience - Less than 1 year months\n'
#  'ACCESS CONTROL LISTS- Exprience - 6 months\n'
#  'DHCP Snooping- Exprience - Less than 1 year months\n'
#  'Private Vlan- Exprience - Less than 1 year months\n'
#  'VLAN Hopping- Exprience - Less than 1 year months\n'
#  'VPN- Exprience - Less than 1 year months\n'
#  'Routing protocols-RIP,EIGRP,OSPF,BGP- Exprience - Less than 1 year months\n'
#  'DM-VPN- Exprience - Less than 1 year months\n'
#  'Switching- Exprience - Less than 1 year months\n'
#  'Control Plane Security- Exprience - Less than 1 year months\n'
#  'Data Plane Security- Exprience - Less than 1 year months\n'
#  'Management Plane Security- Exprience - Less than 1 year months\n'
#  'Network Telemetary- Exprience - Less than 1 year months\n'
#  'Firewall- Exprience - Less than 1 year months\n'
#  'Firewall Filtering Technologies- Exprience - Less than 1 year months\n'
#  'ASA Failovers- Exprience - Less than 1 year months\n'
#  'Zone Based Firewall- Exprience - Less than 1 year months\n'
#  'Reputation Based Firewall- Exprience - Less than 1 year months\n'
#  'Security Context- Exprience - Less than 1 year months\n'
#  'Security- Exprience - Less than 1 year monthsCompany Details \n'
#  'company - Stormfur Technologies LLP\n'
#  'description - Network Security Engineer\n'
#  'Stromfur Technologies LLP,\n'
#  'August 2018-Present\n'
#  ' Troubleshoot firewall related incidents for customers.\n'
#  ' Solve technical problems relating to installing security solutions.\n'
#  ' Analyze security requirements of network system.\n'
#  ' Reviewed configuration and maintained Cisco ASA Firewalls, routers, and '
#  'switches.\n'
#  ' Reviewed and modified access control lists (ACLs) on network switching and '
#  'routing equipment as needed to maintain security standards.\n'
#  ' Participated in core network team to upgrade corporate network.\n'
#  ' Maintained network security technologies and services.\n'
#  ' Interacted with clients and analyzed operational requirements.\n'
#  ' Install and configured of IPSEC and SSL VPN.\n'
#  ' Reviewed and configured VLAN, Routing Protocols (RIP, OSPF, EIGRP), NAT.\n'
#  ' Support for client in various networking issues.')

# %%
talent_pool[talent_pool["ID"] == cv_id]["Resume"].values[0]
# Out:
# 'Skill Set Cisco Certified Network Associates (CCNA): -  Basic knowledge of networking such as Ethernet mediums, ethernet communication, types of Ethernet communication devices etc.  IPv4 (Subnetting, Supernetting)  Basic configuration of Routing, Switching, Access lists, Network Address Translation (NAT), Virtual LANs (VLANs) etc Cisco Certified Network Associates (CCNA-Security): -  Basic security goals and need.  Different types of attacks like access attacks, reconnaissance strategies etc.  Basic configuration of firewalls.  Mitigation techniques such as access control lists, private VLANs, VLAN hopping, IP source guard, DHCP snooping, Authentication, Authorization & Accounting (AAA), IP Security (IPsec) etc. Cisco Certified Network Professional (CCNP-Routing, Switching & MPLS): -  Routing-Configuration and concept of EIGRP, OSPF and BGP.  Switching-Virtual LANs (VLANs), spanning tree protocol (STP), queuing etc.  MPLS (Multi-Protocol Label Switching) -Basic idea about working, types and modes of MPLS, penultimate hopping in mpls etc. Cisco Certified Network Professional Security (ASA Module): -  Knowledge of Control Plane Security, Management Plane Security and Data Plane Security.  Knowledge of Network Telemetary (NTP, NetFlow, Logging), NAT fundamental on ASA.  Firewall filtering technologies, ASA modes of deployment, ASA failover, Security context, Reputation based firewall, Identity firewall, Zone based firewall. Projects T.E. Project: Title: -Temperature Controlled Cooling Fan Academic Year: 2016-2017 (sem-5) Description:  This project simply senses the temperature level and turn ON the FAN when temperature is above set limit. This project was developed with an aim to control the temperature of devices and reduce the damages of the devices because of heating. Title:- Automatic Plant Watering System Academic Year: 2016-2017 (sem-6) Description:  This project simply senses the moisture level and turn ON the water pump when moisture is Education Details \nJanuary 2018 B.E Technology Mumbai, Maharashtra Mumbai university\n H.S.C Mahatma Gandhi High  Maharashtra State Board\n S.S.C. Mahatma Gandhi High  Maharashtra State Board\n    School & Junior College\nNetwork Security Enginner \nNetwork Security Engineer\nSkill Details \nNetworking- Exprience - Less than 1 year months\nSubnetting,Supernetting- Exprience - Less than 1 year months\nAccess Lists- Exprience - Less than 1 year months\nACLS- Exprience - 6 months\nNetwork Address Translation(NAT)- Exprience - Less than 1 year months\nVLAN- Exprience - Less than 1 year months\nAAA- Exprience - Less than 1 year months\nIPSec- Exprience - Less than 1 year months\nACCESS CONTROL LISTS- Exprience - 6 months\nDHCP Snooping- Exprience - Less than 1 year months\nPrivate Vlan- Exprience - Less than 1 year months\nVLAN Hopping- Exprience - Less than 1 year months\nVPN- Exprience - Less than 1 year months\nRouting protocols-RIP,EIGRP,OSPF,BGP- Exprience - Less than 1 year months\nDM-VPN- Exprience - Less than 1 year months\nSwitching- Exprience - Less than 1 year months\nControl Plane Security- Exprience - Less than 1 year months\nData Plane Security- Exprience - Less than 1 year months\nManagement Plane Security- Exprience - Less than 1 year months\nNetwork Telemetary- Exprience - Less than 1 year months\nFirewall- Exprience - Less than 1 year months\nFirewall Filtering Technologies- Exprience - Less than 1 year months\nASA Failovers- Exprience - Less than 1 year months\nZone Based Firewall- Exprience - Less than 1 year months\nReputation Based Firewall- Exprience - Less than 1 year months\nSecurity Context- Exprience - Less than 1 year months\nSecurity- Exprience - Less than 1 year monthsCompany Details \ncompany - Stormfur Technologies LLP\ndescription - Network Security Engineer\nStromfur Technologies LLP,\nAugust 2018-Present\n Troubleshoot firewall related incidents for customers.\n Solve technical problems relating to installing security solutions.\n Analyze security requiremen ...

# %%
talent_pool[talent_pool["ID"] == cv_id]["Resume"].values[0]
# Out:
# 'Skill Set Cisco Certified Network Associates (CCNA): -  Basic knowledge of networking such as Ethernet mediums, ethernet communication, types of Ethernet communication devices etc.  IPv4 (Subnetting, Supernetting)  Basic configuration of Routing, Switching, Access lists, Network Address Translation (NAT), Virtual LANs (VLANs) etc Cisco Certified Network Associates (CCNA-Security): -  Basic security goals and need.  Different types of attacks like access attacks, reconnaissance strategies etc.  Basic configuration of firewalls.  Mitigation techniques such as access control lists, private VLANs, VLAN hopping, IP source guard, DHCP snooping, Authentication, Authorization & Accounting (AAA), IP Security (IPsec) etc. Cisco Certified Network Professional (CCNP-Routing, Switching & MPLS): -  Routing-Configuration and concept of EIGRP, OSPF and BGP.  Switching-Virtual LANs (VLANs), spanning tree protocol (STP), queuing etc.  MPLS (Multi-Protocol Label Switching) -Basic idea about working, types and modes of MPLS, penultimate hopping in mpls etc. Cisco Certified Network Professional Security (ASA Module): -  Knowledge of Control Plane Security, Management Plane Security and Data Plane Security.  Knowledge of Network Telemetary (NTP, NetFlow, Logging), NAT fundamental on ASA.  Firewall filtering technologies, ASA modes of deployment, ASA failover, Security context, Reputation based firewall, Identity firewall, Zone based firewall. Projects T.E. Project: Title: -Temperature Controlled Cooling Fan Academic Year: 2016-2017 (sem-5) Description:  This project simply senses the temperature level and turn ON the FAN when temperature is above set limit. This project was developed with an aim to control the temperature of devices and reduce the damages of the devices because of heating. Title:- Automatic Plant Watering System Academic Year: 2016-2017 (sem-6) Description:  This project simply senses the moisture level and turn ON the water pump when moisture is Education Details \nJanuary 2018 B.E Technology Mumbai, Maharashtra Mumbai university\n H.S.C Mahatma Gandhi High  Maharashtra State Board\n S.S.C. Mahatma Gandhi High  Maharashtra State Board\n    School & Junior College\nNetwork Security Enginner \nNetwork Security Engineer\nSkill Details \nNetworking- Exprience - Less than 1 year months\nSubnetting,Supernetting- Exprience - Less than 1 year months\nAccess Lists- Exprience - Less than 1 year months\nACLS- Exprience - 6 months\nNetwork Address Translation(NAT)- Exprience - Less than 1 year months\nVLAN- Exprience - Less than 1 year months\nAAA- Exprience - Less than 1 year months\nIPSec- Exprience - Less than 1 year months\nACCESS CONTROL LISTS- Exprience - 6 months\nDHCP Snooping- Exprience - Less than 1 year months\nPrivate Vlan- Exprience - Less than 1 year months\nVLAN Hopping- Exprience - Less than 1 year months\nVPN- Exprience - Less than 1 year months\nRouting protocols-RIP,EIGRP,OSPF,BGP- Exprience - Less than 1 year months\nDM-VPN- Exprience - Less than 1 year months\nSwitching- Exprience - Less than 1 year months\nControl Plane Security- Exprience - Less than 1 year months\nData Plane Security- Exprience - Less than 1 year months\nManagement Plane Security- Exprience - Less than 1 year months\nNetwork Telemetary- Exprience - Less than 1 year months\nFirewall- Exprience - Less than 1 year months\nFirewall Filtering Technologies- Exprience - Less than 1 year months\nASA Failovers- Exprience - Less than 1 year months\nZone Based Firewall- Exprience - Less than 1 year months\nReputation Based Firewall- Exprience - Less than 1 year months\nSecurity Context- Exprience - Less than 1 year months\nSecurity- Exprience - Less than 1 year monthsCompany Details \ncompany - Stormfur Technologies LLP\ndescription - Network Security Engineer\nStromfur Technologies LLP,\nAugust 2018-Present\n Troubleshoot firewall related incidents for customers.\n Solve technical problems relating to installing security solutions.\n Analyze security requiremen ...

# %%
for file in Path("output_20240830_0136").iterdir():
  if file.is_file() and file.name.startswith(f"{job_id}_{cv_id}"):
    if file.name.endswith(".csv"):
      df = pd.read_csv(file)
      display(df)
    if file.name.endswith(".json"):
      model_name = file.name.split("_")[2][:-5]
      with open(file, "r") as f:
        data = json.load(f)
        print("-"*100)
        print(model_name)
        print("-"*100)
        pprint(data)
# Out:
#     Model  original_technical_skills  recalibrated_technical_skills  \
# 0  llama3                         20                             30
# 1     gpt                         85                             90
#
#    original_soft_skills  recalibrated_soft_skills  \
# 0                     0                         0
# 1                     0                         0
#
#    original_required_experience  recalibrated_required_experience  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
#
#    original_qualifications  recalibrated_qualifications suitability
# 0                        0                          NaN          no
# 1                       70                          NaN         yes
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'assessment': {'missing_skills': [{'Software Engineering': 'essential'},
#                                    {'Development Execution Improvement Action Plan': 'essential'}],
#                 'potential_concerns': ['Lack of relevant experience in '
#                                        'software engineering and development '
#                                        'execution improvement action plan'],
#                 'strengths': ['Networking Experience'],
#                 'suitability': 'no'},
#  'deeper_analysis': {'inferred_experiences': []},
#  'job_description_analysis': {'education_qualifications': [],
#                               'required_experience': [4],
#                               'soft_skills': ['Communication',
#                                               'Problem-solving',
#                                               'Collaboration'],
#                               'technical_skills': [{'Software Engineering': 'essential'},
#                                                    {'Development Execution Improvement Action Plan': 'essential'},
#                                                    {'Manages Small Medium-Sized Complex Team Project Model Compliance Company Policy Procedure Support Company Standard Ethic Integrity': 'advantageous'},
#                                                    {'Provides Support Implementation Business Solution Provides Support Business New Existing System Troubleshoots Business Production Issue': 'advantageous'}]},
#  'recalibrated_scores': {'education_qualifications': 0,
#                          'experience': 20,
#                          'soft_skills': 0,
#                          'technical_skills': 30},
#  'resume_evaluation': {'missing_skills': [{'Software Engineering': 'essential'},
#                                           {'Development Execution Improvement Action Plan': 'essential'}],
#                        'original_scores': {'qualifications': 0,
#                                            'relevant_experience': 10,
#                                            'soft_skills': 0,
#                                            'technical_skills': 20}}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'assessment': {'missing_skills': [],
#                 'potential_concerns': [],
#                 'strengths': ['Strong technical skills in Cisco networking '
#                               'certifications',
#                               'Relevant work experience in network security'],
#                 'suitability': 'yes'},
#  'deeper_analysis': {'inferred_experiences': ['MPLS (Multi-Protocol Label '
#                                               'Switching)']},
#  'job_description_analysis': {'education_qualifications': ["Bachelor's degree "
#                                                            'in Computer '
#                                                            'Science or related '
#                                                            'field'],
#                               'required_experience': 4,
#                               'soft_skills': [],
#                               'technical_skills': {'Cisco Certified Network Associates (CCNA)': 'essential',
#                                                    'Cisco Certified Network Associates (CCNA-Security)': 'essential',
#                                                    'Cisco Certified Network Professional (CCNP-Routing, Switching & MPLS)': 'essential',
#                                                    'Cisco Certified Network Professional Security (ASA Module)': 'essential'}},
#  'recalibrated_scores': {'education_qualifications': 70,
#                          'experience': 90,
#                          'soft_skills': 0,
#                          'technical_skills': 90},
#  'resume_evaluation': {'missing_skills': ['MPLS (Multi-Protocol Label '
#                                           'Switching)'],
#                        'original_scores': {'qualifications': 70,
#                                            'relevant_experience': 90,
#                                            'soft_skills': 0,
#                                            'technical_skills': 85}}}

# %%
# extract all json for the same jd 
for file in Path("output_20240830_0136").iterdir():
  if file.is_file() and file.name.startswith(f"{job_id}") and file.name.endswith(".json"):
      model_name = file.name.split("_")[2][:-5]
      with open(file, "r") as f:
          data = json.load(f)
          print("-"*100)
          print(model_name)
          print("-"*100)

          try:
            pprint(data["job_description_analysis"])
          except:
            print("no job description analysis")
# Out:
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'.Net': 'essential',
#                       'C': 'essential',
#                       'C++': 'essential',
#                       'CSS': 'essential',
#                       'HTML5': 'essential',
#                       'IBM DB2': 'advantageous',
#                       'IBM Rational Rose': 'advantageous',
#                       'Java': 'essential',
#                       'Javascript': 'advantageous',
#                       'MY-SQL': 'advantageous',
#                       'MapReduce': 'essential',
#                       'Oracle (PL-SQL)': 'advantageous',
#                       'Python': 'advantageous',
#                       'R': 'advantageous',
#                       'Red Hat 7': 'advantageous',
#                       'UNIX': 'advantageous',
#                       'Vista': 'advantageous',
#                       'Weka': 'advantageous',
#                       'Windows 7': 'advantageous',
#                       'Windows XP': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': [{'Application Servers': 'essential'},
#                       {'Database': 'essential'},
#                       {'Report Tool': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Culturally fit for startup environment',
#                  'Enthusiastic to learn new technologies'],
#  'technical_skills': [{'Ethereum': 'essential'},
#                       {'Smart Contracts': 'essential'},
#                       {'Solidity': 'essential'},
#                       {'Golang': 'advantageous'},
#                       {'Node': 'advantageous'},
#                       {'Angular': 'advantageous'},
#                       {'React': 'advantageous'},
#                       {'MongoDB': 'advantageous'},
#                       {'PostgreSQL': 'advantageous'},
#                       {'MySQL': 'advantageous'},
#                       {'AWS': 'advantageous'},
#                       {'Docker': 'advantageous'},
#                       {'Microservices': 'advantageous'},
#                       {'Blockchain': 'essential'},
#                       {'Protocol': 'essential'},
#                       {'Consensus': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree computer science related "
#                               'field'],
#  'required_experience': [4],
#  'soft_skills': ['mission help people save money live better',
#                  'help brightest mind technology merchandising marketing '
#                  'supply chain talent reimagining intersection digital '
#                  'physical shopping'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development execution improvement action plan': 'essential'},
#                       {'manages small medium-sized complex team project model compliance company policy procedure support company standard ethic integrity': 'advantageous'},
#                       {'provides support implementation business solution provides support business new existing system troubleshoots business production issue': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# no job description analysis
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'Operating Systems': 'essential'},
#                       {'Database Technologies': 'essential'},
#                       {'Monitoring and Ticketing Tools': 'essential'},
#                       {'Web Server': 'essential'},
#                       {'Database Tools': 'essential'},
#                       {'SQL Server': 'advantageous'},
#                       {'Sybase ASE Server': 'advantageous'},
#                       {'Oracle': 'advantageous'},
#                       {'MongoDB': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'AWS': 'essential',
#                       'Keras': 'essential',
#                       'Machine learning': 'essential',
#                       'Python': 'essential',
#                       'Scipy': 'essential',
#                       'Sklearn': 'essential',
#                       'Statsmodels': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'Hadoop': 'essential'},
#                       {'MapReduce': 'essential'},
#                       {'Pig': 'essential'},
#                       {'Hive': 'essential'},
#                       {'Sqoop': 'essential'},
#                       {'Spark': 'advantageous'},
#                       {'Scala': 'advantageous'},
#                       {'Java': 'advantageous'},
#                       {'Linux': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree computer science related "
#                               'field'],
#  'required_experience': [4],
#  'soft_skills': ['mission help people save money live better',
#                  'help brightest mind technology merchandising marketing '
#                  'supply chain talent reimagining intersection digital '
#                  'physical shopping'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development execution improvement action plan': 'essential'},
#                       {'manages small medium-sized complex team project model compliance company policy procedure support company standard ethic integrity': 'advantageous'},
#                       {'provides support implementation business solution provides support business new existing system troubleshoots business production issue': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Ajax': 'advantageous',
#                       'CSS': 'advantageous',
#                       'HTML': 'advantageous',
#                       'Hibernate': 'essential',
#                       'Java': 'essential',
#                       'Spring': 'essential',
#                       'jQuery': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'HBase': 'essential',
#                       'Hadoop': 'essential',
#                       'Hive': 'essential',
#                       'Java': 'advantageous',
#                       'Linux': 'advantageous',
#                       'MapReduce': 'essential',
#                       'NoSQL': 'advantageous',
#                       'Oozie': 'advantageous',
#                       'Pig': 'essential',
#                       'Python': 'advantageous',
#                       'SQL': 'essential',
#                       'Scala': 'essential',
#                       'Spark': 'essential',
#                       'Sqoop': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['High energy levels', 'Result oriented'],
#  'technical_skills': {'CSS': 'advantageous',
#                       'Deep Learning': 'essential',
#                       'HTML': 'advantageous',
#                       'Machine Learning': 'essential',
#                       'NLP': 'essential',
#                       'Python': 'essential',
#                       'SQL': 'essential',
#                       'Web Scraping': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# anthropic
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management',
#                  'project management',
#                  'compliance with company policies',
#                  'ethical integrity'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'ecommerce application development': 'essential'},
#                       {'mobile software development': 'essential'},
#                       {'scalable systems': 'essential'},
#                       {'troubleshooting': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': [],
#  'required_experience': [5],
#  'soft_skills': ['Good Communication skills',
#                  'Self-confident and can adapt myself to all work environments',
#                  'Patient listener & quick learner'],
#  'technical_skills': [{'SQL Server': 'essential'},
#                       {'Postgresql': 'essential'},
#                       {'Oracle': 'essential'},
#                       {'Redhat Linux': 'essential'},
#                       {'Windows Server': 'advantageous'},
#                       {'Linux': 'advantageous'},
#                       {'MS SQL SERVER': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Angular 6': 'advantageous',
#                       'CSS': 'advantageous',
#                       'Computer Vision': 'advantageous',
#                       'Database Visualization': 'essential',
#                       'Deep Learning': 'advantageous',
#                       'Docker': 'advantageous',
#                       'Git': 'advantageous',
#                       'HTML': 'advantageous',
#                       'Java': 'essential',
#                       'JavaScript': 'essential',
#                       'Machine Learning': 'essential',
#                       'Python': 'essential',
#                       'Regular Expression': 'advantageous',
#                       'SQL': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree computer science related "
#                               'field'],
#  'required_experience': [4],
#  'soft_skills': ['up-to-date expertise',
#                  'mission help people save money live better help brightest '
#                  'mind technology merchandising marketing supply chain talent '
#                  'reimagining intersection digital physical shopping'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development execution improvement action plan': 'essential'},
#                       {'manages small medium-sized complex team project model compliance company policy procedure support company standard ethic integrity': 'advantageous'},
#                       {'provides support implementation business solution provides support business new existing system troubleshoots business production issue': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Always on availability group': 'essential',
#                       'Database mirroring': 'essential',
#                       'Installation, upgrade, migration, and patching': 'essential',
#                       'Log shipping': 'essential',
#                       'MS SQL Server': 'essential',
#                       'Microsoft Azure': 'advantageous',
#                       'Netezza': 'advantageous',
#                       'Oracle': 'advantageous',
#                       'Performance tuning': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Multitasking',
#                  'Team player',
#                  'Excellent communication skills',
#                  'Quick learner',
#                  'Leadership qualities'],
#  'technical_skills': [{'SQL': 'essential'},
#                       {'Oracle v10, v11, v12': 'essential'},
#                       {'R programming': 'advantageous'},
#                       {'Python': 'advantageous'},
#                       {'Linear regression': 'advantageous'},
#                       {'Machine learning and statistical modelling techniques': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Integrity', 'Ethic'],
#  'technical_skills': [{'Oracle DBA': 'essential'},
#                       {'Software Engineering': 'essential'},
#                       {'Development Execution Improvement Action Plan': 'essential'},
#                       {'Team Project Model Compliance': 'essential'},
#                       {'Company Policy Procedure Support': 'advantageous'},
#                       {'Business Solution Implementation': 'advantageous'},
#                       {'Troubleshooting Business Production Issue': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development': 'essential'},
#                       {'ecommerce application': 'essential'},
#                       {'mobile software': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's Degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Team Management',
#                  'Project Model Compliance',
#                  'Company Policy Procedure Support',
#                  'Integrity',
#                  'Ethic'],
#  'technical_skills': [{'Python': 'essential'},
#                       {'Software Engineering': 'essential'},
#                       {'Ecommerce Application Development': 'advantageous'},
#                       {'Mobile Software Development': 'advantageous'},
#                       {'Scalable Application Building': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'Agile Methodology': 'essential',
#                       'Ajax': 'essential',
#                       'Angular JS': 'advantageous',
#                       'Bitbucket': 'essential',
#                       'Data Base Design': 'essential',
#                       'DevOps Methodology': 'essential',
#                       'GIT': 'essential',
#                       'HTML': 'essential',
#                       'JIRA Tool': 'essential',
#                       'JavaScript': 'essential',
#                       'MySql': 'essential',
#                       'PHP': 'essential',
#                       'Python': 'essential',
#                       'Scrum Framework': 'essential',
#                       'XML': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Adaptability',
#                  'Hard Worker',
#                  'Self Motivated',
#                  'Positive Attitude'],
#  'technical_skills': [{'C#': 'essential'},
#                       {'ASP .NET MVC': 'essential'},
#                       {'HTML': 'essential'},
#                       {'CSS': 'essential'},
#                       {'JavaScript': 'essential'},
#                       {'AngularJs': 'essential'},
#                       {'Entity Framework': 'essential'},
#                       {'SQL Server': 'advantageous'},
#                       {'Visual Studio': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development': 'essential'},
#                       {'ecommerce application': 'essential'},
#                       {'mobile software': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Troubleshooting', 'Communication', 'Teamwork'],
#  'technical_skills': [{'Microsoft Window Server': 'essential'},
#                       {'SQL Server': 'essential'},
#                       {'Sybase ASE Server': 'essential'},
#                       {'Oracle': 'essential'},
#                       {'MongoDB': 'advantageous'},
#                       {'HP Service Manager': 'advantageous'},
#                       {'Solar winds DPA': 'advantageous'},
#                       {'JIRA': 'advantageous'},
#                       {'IIS 7.0': 'advantageous'},
#                       {'SSMS': 'essential'},
#                       {'DBArtisan': 'advantageous'},
#                       {'Studio 3T': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'C': 'essential'},
#                       {'C++': 'essential'},
#                       {'Java': 'essential'},
#                       {'.Net': 'essential'},
#                       {'J2EE': 'essential'},
#                       {'HTML5': 'advantageous'},
#                       {'CSS': 'advantageous'},
#                       {'MapReduce Scripting Languages': 'essential'},
#                       {'Javascript': 'advantageous'},
#                       {'Python': 'advantageous'},
#                       {'Oracle (PL-SQL)': 'essential'},
#                       {'MY-SQL': 'essential'},
#                       {'IBM DB2': 'essential'},
#                       {'IBM Rational Rose': 'advantageous'},
#                       {'R': 'advantageous'},
#                       {'Weka': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': [],
#  'required_experience': [4],
#  'soft_skills': ['Communication', 'Problem-solving', 'Collaboration'],
#  'technical_skills': [{'Software Engineering': 'essential'},
#                       {'Development Execution Improvement Action Plan': 'essential'},
#                       {'Manages Small Medium-Sized Complex Team Project Model Compliance Company Policy Procedure Support Company Standard Ethic Integrity': 'advantageous'},
#                       {'Provides Support Implementation Business Solution Provides Support Business New Existing System Troubleshoots Business Production Issue': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development': 'essential'},
#                       {'ecommerce application': 'essential'},
#                       {'mobile software': 'essential'},
#                       {'python': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['multitasking',
#                  'team player',
#                  'communication skills',
#                  'leadership',
#                  'networking'],
#  'technical_skills': {'Oracle': 'essential',
#                       'Python': 'advantageous',
#                       'R programming': 'advantageous',
#                       'SQL': 'essential',
#                       'linear regression': 'advantageous',
#                       'machine learning': 'advantageous',
#                       'statistical modelling techniques': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'Beautiful Soup': 'advantageous',
#                       'Django': 'essential',
#                       'HTML': 'essential',
#                       'Matplotlib': 'advantageous',
#                       'MySQL': 'essential',
#                       'Numpy': 'advantageous',
#                       'Pandas': 'advantageous',
#                       'Python': 'essential',
#                       'Requests': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Team leading', 'Self-motivated', 'Hard working'],
#  'technical_skills': [{'Core Java': 'essential'},
#                       {'JSP': 'essential'},
#                       {'Servlet': 'essential'},
#                       {'Spring': 'essential'},
#                       {'Hibernate': 'essential'},
#                       {'Struts': 'advantageous'},
#                       {'JavaScript': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Teamwork', 'Problem-solving', 'Communication'],
#  'technical_skills': {'Backup and recovery': 'essential',
#                       'Database Management': 'essential',
#                       'Database Up-gradation': 'essential',
#                       'Database links': 'advantageous',
#                       'Monitoring the database': 'essential',
#                       'Oracle DBA': 'essential',
#                       'Tablespaces management': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['articulate leadership qualities', 'teamwork'],
#  'technical_skills': [{'Hadoop': 'essential'},
#                       {'Spark': 'essential'},
#                       {'Sqoop': 'essential'},
#                       {'Pig': 'essential'},
#                       {'Hive': 'essential'},
#                       {'Flume': 'advantageous'},
#                       {'Tableau': 'advantageous'},
#                       {'Beyond Compare': 'advantageous'},
#                       {'Linux': 'advantageous'},
#                       {'Ubuntu': 'advantageous'},
#                       {'Windows 2007/08': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': [{'Oracle': 'essential'},
#                       {'Informatica': 'essential'},
#                       {'SQL': 'essential'},
#                       {'PLSQL': 'essential'},
#                       {'ETL': 'essential'},
#                       {'Unix': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'Network Technologies': 'essential',
#                       'Operating Systems': 'essential',
#                       'Server Technologies': 'essential',
#                       'Virtualisation': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': ['software engineering',
#                       'development',
#                       'ecommerce application',
#                       'mobile software']}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'AWS': 'advantageous',
#                       'Automation': 'essential',
#                       'Azure': 'advantageous',
#                       'Cloud Computing': 'essential',
#                       'Python': 'advantageous',
#                       'Shell Scripting': 'essential',
#                       'Solution Architect': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Browser Scripting': 'essential',
#                       'Database': 'essential',
#                       'Development Tools': 'essential',
#                       'Dot Net Technologies': 'essential',
#                       'Front-end-framework': 'essential',
#                       'Language': 'essential',
#                       'Operating Systems': 'essential',
#                       'Web Technologies': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork', 'leadership'],
#  'technical_skills': [{'Bitcoin': 'advantageous'},
#                       {'Ethereum': 'advantageous'},
#                       {'Solidity': 'essential'},
#                       {'Hyperledger': 'advantageous'},
#                       {'Go': 'advantageous'},
#                       {'R3 Corda': 'advantageous'},
#                       {'Tendermint': 'advantageous'},
#                       {'Nodejs': 'essential'},
#                       {'C Programming': 'essential'},
#                       {'Java': 'essential'},
#                       {'Machine Learning': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'C': 'essential',
#                       'Data Science': 'essential',
#                       'HTML': 'advantageous',
#                       'Machine Learning': 'essential',
#                       'Python': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree",
#                               'computer science related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'C++': 'essential'},
#                       {'C': 'essential'},
#                       {'Java': 'essential'},
#                       {'DS': 'essential'},
#                       {'Jdbc': 'advantageous'},
#                       {'Hibernate': 'advantageous'},
#                       {'Java J2EE': 'advantageous'},
#                       {'JavaScript': 'advantageous'},
#                       {'JQuery': 'advantageous'},
#                       {'Ajax': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Culturally fit for startup environment',
#                  'Enthusiastic to learn new technologies'],
#  'technical_skills': {'AWS': 'advantageous',
#                       'Angular': 'advantageous',
#                       'Blockchain': 'advantageous',
#                       'Consensus': 'advantageous',
#                       'Docker': 'advantageous',
#                       'Ethereum': 'advantageous',
#                       'Golang': 'advantageous',
#                       'Microservices': 'advantageous',
#                       'MongoDB': 'advantageous',
#                       'MySql': 'advantageous',
#                       'Node': 'advantageous',
#                       'PostGresql': 'advantageous',
#                       'Protocol': 'advantageous',
#                       'React': 'advantageous',
#                       'Smart Contracts': 'essential',
#                       'Solidity': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'ANT': 'essential',
#                       'Ansible': 'essential',
#                       'Apache Tomcat server': 'advantageous',
#                       'Bitbucket': 'essential',
#                       'C': 'essential',
#                       'Core Java': 'essential',
#                       'DevOps methodologies': 'essential',
#                       'GIT': 'essential',
#                       'Jenkins': 'essential',
#                       'Maven': 'essential',
#                       'Shell Script': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Problem-solving',
#                  'Team Management',
#                  'Communication',
#                  'Adaptability'],
#  'technical_skills': [{'Java': 'essential'},
#                       {'JavaScript': 'essential'},
#                       {'Software Engineering': 'essential'},
#                       {'Ecommerce Application Development': 'essential'},
#                       {'Mobile Software Development': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'C': 'essential',
#                       'CSS': 'advantageous',
#                       'HTML': 'advantageous',
#                       'Hibernate': 'advantageous',
#                       'Java': 'essential',
#                       'JavaEE': 'advantageous',
#                       'Javascript': 'advantageous',
#                       'MySQL': 'advantageous',
#                       'PL/SQL': 'essential',
#                       'SQL': 'essential',
#                       'Spring': 'advantageous',
#                       'jQuery': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Ajax': 'advantageous',
#                       'Hibernate': 'advantageous',
#                       'J2EE': 'advantageous',
#                       'JQuery': 'advantageous',
#                       'Java': 'essential',
#                       'Javascript': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# anthropic
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management',
#                  'project management',
#                  'compliance',
#                  'ethics',
#                  'integrity',
#                  'problem-solving'],
#  'technical_skills': [{'software_engineering': 'essential'},
#                       {'ecommerce_development': 'essential'},
#                       {'mobile_software_development': 'advantageous'},
#                       {'scalable_applications': 'essential'},
#                       {'troubleshooting': 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': []}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['teamwork',
#                  'communication',
#                  'problem-solving',
#                  'adaptability'],
#  'technical_skills': {'Angular': 'advantageous',
#                       'Bitcoin': 'advantageous',
#                       'C Programming': 'essential',
#                       'Cloud Computing': 'advantageous',
#                       'Computer Networking': 'essential',
#                       'Computer Vision': 'essential',
#                       'Data Analytics': 'essential',
#                       'Ethereum': 'advantageous',
#                       'Go': 'advantageous',
#                       'Hyperledger': 'advantageous',
#                       'Java': 'essential',
#                       'Machine Learning': 'essential',
#                       'Nodejs': 'essential',
#                       'R3 Corda': 'advantageous',
#                       'Reactjs': 'advantageous',
#                       'Server Admin': 'advantageous',
#                       'Solidity': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': [],
#  'required_experience': [4],
#  'soft_skills': ['Liaising', 'Problem Analysis & Resolution skills'],
#  'technical_skills': [{'SQL': 'essential'},
#                       {'PLSQL': 'essential'},
#                       {'Informatica 9.1': 'essential'},
#                       {'Oracle 11g': 'essential'},
#                       {'Unix': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Operating System': 'essential',
#                       'Oracle Database Administration': 'essential',
#                       'SQL': 'essential',
#                       'UNIX Shell Scripting': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Leadership',
#                  'Team Management',
#                  'Communication',
#                  'Problem-Solving'],
#  'technical_skills': [{'Cloud Computing': 'essential'},
#                       {'Shell Scripting': 'essential'},
#                       {'Python': 'advantageous'},
#                       {'Automation': 'essential'},
#                       {'Solution Architect': 'advantageous'},
#                       {'Azure': 'advantageous'},
#                       {'AWS': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Strong communication',
#                  'Collaboration & team building skills',
#                  'Grasping new technical concepts quickly'],
#  'technical_skills': [{'Java': 'essential'},
#                       {'SQL': 'essential'},
#                       {'PL/SQL': 'essential'},
#                       {'C': 'advantageous'},
#                       {'C++': 'advantageous'},
#                       {'Bootstrap': 'advantageous'},
#                       {'JSP': 'advantageous'},
#                       {'Ext JS': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Good Communication skills',
#                  'Self-confidence',
#                  'Adaptability',
#                  'Responsibility',
#                  'Teamwork',
#                  'Listening skills',
#                  'Quick learner'],
#  'technical_skills': {'ASH Reports': 'advantageous',
#                       'AWR Reports': 'advantageous',
#                       'Always-On Availability Groups': 'essential',
#                       'Data Guard': 'advantageous',
#                       'Database Backup': 'advantageous',
#                       'Expdp/Impdp': 'advantageous',
#                       'Flashback Technologies': 'advantageous',
#                       'GSSAPI Authentication': 'advantageous',
#                       'LDAP Authentication': 'advantageous',
#                       'Linked Servers': 'essential',
#                       'Linux': 'essential',
#                       'Listener Configuration': 'advantageous',
#                       'Logical Replication': 'advantageous',
#                       'Maintenance Tasks': 'essential',
#                       'Oracle Database': 'essential',
#                       'Postgresql': 'advantageous',
#                       'RAC': 'advantageous',
#                       'SQL': 'essential',
#                       'SQL Cluster': 'essential',
#                       'SQL Server Administration': 'essential',
#                       'Tnsnames Configuration': 'advantageous',
# ...
#                       {'MongoDB': 'advantageous'},
#                       {'MySql': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'Design Studio': 'advantageous',
#                       'HANA': 'essential',
#                       'IDT': 'advantageous',
#                       'SAP BO 4.2': 'essential',
#                       'SAP Business Intelligence': 'essential',
#                       'SQL': 'essential',
#                       'Webi': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development': 'essential'},
#                       {'ecommerce application': 'essential'},
#                       {'mobile software': 'essential'},
#                       {'asp.net': 'advantageous'},
#                       {'c#': 'advantageous'},
#                       {'html': 'advantageous'},
#                       {'css': 'advantageous'},
#                       {'sql': 'advantageous'},
#                       {'javascript': 'advantageous'},
#                       {'sql server': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'Basic Core Java': 'essential',
#                       'Basic Python': 'advantageous',
#                       'Data Warehousing': 'essential',
#                       'ETL': 'essential',
#                       'Oracle 11g': 'advantageous',
#                       'SAP BO': 'advantageous',
#                       'SAP BODS': 'essential',
#                       'SQL/PL SQL': 'essential',
#                       'Sybase': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['teamwork', 'communication', 'problem-solving'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development execution improvement action plan': 'essential'},
#                       {'manages small medium-sized complex team project model compliance company policy procedure support company standard ethic integrity': 'advantageous'},
#                       {'provides support implementation business solution provides support business new existing system troubleshoots business production issue': 'advantageous'},
#                       {"minimum qualification bachelor's degree computer science related field 4 year experience building scalable ecommerce application mobile software": 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Problem solving', 'Communication', 'Flexibility'],
#  'technical_skills': {'Data Science': 'essential',
#                       'Deep Learning': 'essential',
#                       'GCP': 'essential',
#                       'Machine Learning': 'essential',
#                       'Numpy': 'essential',
#                       'Pandas': 'essential',
#                       'Python': 'essential',
#                       'Scikit': 'essential',
#                       'Tensorflow': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'software engineering': 'essential'},
#                       {'development execution improvement action plan': 'essential'},
#                       {'manages small medium-sized complex team project model compliance company policy procedure support company standard ethic integrity': 'advantageous'},
#                       {'provides support implementation business solution provides support business new existing system troubleshoots business production issue': 'advantageous'},
#                       {"minimum qualification bachelor's degree computer science related field": 'essential'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'Ab Initio': 'advantageous',
#                       'Data Warehouse': 'essential',
#                       'SQL': 'essential',
#                       'Unix': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': {'HDFS': 'essential',
#                       'Hadoop': 'essential',
#                       'Hive': 'essential',
#                       'Java': 'advantageous',
#                       'Map Reduce': 'essential',
#                       'Sqoop': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['Strong project experience',
#                  'Excellent communication skills',
#                  'Team participation',
#                  'Inter-team coordination',
#                  'Customer-oriented attitude'],
#  'technical_skills': [{'SAP ABAP': 'essential'},
#                       {'SAP Netweaver Gateway / oData / Fiori': 'essential'},
#                       {'SAP S/4HANA': 'essential'},
#                       {'Software Engineering': 'advantageous'},
#                       {'Ecommerce Application Development': 'advantageous'},
#                       {'Mobile Software Development': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': [],
#  'technical_skills': []}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'AJAX': 'essential',
#                       'CSS': 'essential',
#                       'HTML': 'essential',
#                       'Hibernate': 'essential',
#                       'J2EE': 'essential',
#                       'JQUERY': 'essential',
#                       'JSON': 'essential',
#                       'JSP': 'essential',
#                       'Java': 'essential',
#                       'JavaScript': 'essential',
#                       'MVC architecture': 'essential',
#                       'MongoDB': 'advantageous',
#                       'MySql': 'advantageous',
#                       'Servlets': 'essential',
#                       'Spring': 'essential'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree",
#                               'computer science related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'ASP.NET': 'essential'},
#                       {'HTML': 'essential'},
#                       {'CSS': 'essential'},
#                       {'JQuery': 'advantageous'},
#                       {'C': 'advantageous'},
#                       {'C++': 'advantageous'},
#                       {'C#.NET': 'essential'},
#                       {'MVC 5': 'essential'},
#                       {'SQL SERVER 2005/2008/2016': 'essential'},
#                       {'Kindo UI': 'advantageous'},
#                       {'Telerik functions': 'advantageous'},
#                       {'Crystal Report': 'advantageous'},
#                       {'Visual Stadio 2010/2014': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': [],
#  'required_experience': [2],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'ETL': 'essential'},
#                       {'Data Warehousing': 'essential'},
#                       {'SQL/PL SQL': 'essential'},
#                       {'Basic Core Java': 'advantageous'},
#                       {'Basic Python': 'advantageous'},
#                       {'SAP BODS': 'essential'},
#                       {'SAP BO': 'essential'},
#                       {'Oracle 11g': 'essential'},
#                       {'Trusted authentication': 'advantageous'},
#                       {'Vintela sso': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': [{'Java': 'essential'}, {'Javascript': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["bachelor's degree in computer science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'communication', 'problem-solving'],
#  'technical_skills': {'SAP ABAP': 'essential',
#                       'SAP Netweaver Gateway / oData / Fiori': 'essential',
#                       'SAP S/4HANA': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['teamwork', 'communication', 'leadership'],
#  'technical_skills': {'Flume': 'essential',
#                       'Hadoop': 'essential',
#                       'Hive': 'essential',
#                       'Pig': 'essential',
#                       'Scala': 'advantageous',
#                       'Spark': 'essential',
#                       'Sqoop': 'essential',
#                       'Tableau': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# llama3
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': [4],
#  'soft_skills': ['problem-solving', 'communication', 'teamwork'],
#  'technical_skills': [{'Python': 'essential'},
#                       {'MATLAB': 'essential'},
#                       {'Data Science': 'essential'},
#                       {'Machine Learning': 'essential'},
#                       {'HTML': 'advantageous'},
#                       {'Microsoft Word': 'advantageous'},
#                       {'Microsoft Excel': 'advantageous'},
#                       {'Microsoft Powerpoint': 'advantageous'}]}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['Team leading', 'Self-motivated', 'Hard working'],
#  'technical_skills': {'Hard working': 'advantageous',
#                       'Hibernate': 'essential',
#                       'JSP': 'essential',
#                       'Java': 'essential',
#                       'Javascript': 'essential',
#                       'Self-motivated': 'advantageous',
#                       'Servlet': 'essential',
#                       'Spring': 'essential',
#                       'Team leading': 'advantageous'}}
# ----------------------------------------------------------------------------------------------------
# gpt
# ----------------------------------------------------------------------------------------------------
# {'education_qualifications': ["Bachelor's degree in Computer Science or "
#                               'related field'],
#  'required_experience': 4,
#  'soft_skills': ['team management', 'problem-solving', 'communication'],
#  'technical_skills': {'ASP .NET': 'essential',
#                       'C': 'advantageous',
#                       'C#.NET': 'essential',
#                       'C++': 'advantageous',
#                       'CSS': 'essential',
#                       'Crystal Report': 'essential',
#                       'HTML': 'essential',
#                       'Jquery': 'essential',
#                       'MVC 5': 'essential',
#                       'SQL SERVER 2005/2008/2016': 'essential',
#                       'Web Technologies': 'essential'}}

# %% [markdown]
# looks like ChatGPT didnt extract required skills correctly

# %%
from pprint import pprint

pprint(job_pool[job_pool["Job ID"] == job_id]["Job Description"].values[0])
# Out:
# ('position description demonstrates up-to-date expertise software engineering '
#  'applies development execution improvement action plan manages small '
#  'medium-sized complex team project model compliance company policy procedure '
#  'support company standard ethic integrity provides support implementation '
#  'business solution provides support business new existing system '
#  "troubleshoots business production issue minimum qualification bachelor 's "
#  'degree computer science related field 4 year experience building scalable '
#  'ecommerce application mobile software additional preferred qualification '
#  'company summary walmart ecommerce team rapidly innovating evolve define '
#  'future state shopping world ’ largest retailer mission help people save '
#  'money live better help brightest mind technology merchandising marketing '
#  'supply chain talent reimagining intersection digital physical shopping help '
#  'achieve mission position summary walmart lab ’ reinventing world ’ leading '
#  'retail platform leveraging unique strength deliver best customer experience '
#  'wherever customer shop imagine environment one line code one experiment one '
#  'idea ha power catapult entire industry towards smarter future better yet '
#  'imagine power could every day ’ walmart lab tech-empowered people-led ’ team '
#  '4000+ software engineer data scientist designer product manager within '
#  'walmart across world delivering innovation transform customer shop '
#  'enterprise operates technologist solve complex problem walmart building '
#  'solution impact hundred million people world ’ largest retailer')

# %%
pprint(talent_pool[talent_pool["ID"] == cv_id]["Resume"].values[0])
# Out:
# ('Education Details \n'
#  'February 2006 to February 2006 TYBCOM Commerce  mumbai\n'
#  'Business Analyst \n'
#  'Business Analyst\n'
#  'Skill Details \n'
#  'Company Details \n'
#  'company - Motilal Oswal\n'
#  'description - Business Analyst\n'
#  'Handling IT Operation for Institutional Equities \n'
#  'Maintain Daily MIS in Excel for CAG, Research, Derivative, Sales team '
#  'Preparing Auto Dashboard For Research, Sales, Trading team Working on Excel '
#  'Macro to Create Innovative Report \n'
#  'Working on Block Related Data Working on BD Fund from different GEO Working '
#  'on Investors Corporate Meeting to track Corporate Block & Fund Interest in '
#  'Sector\n'
#  'company - FSS\n'
#  'description - Project Description:\n'
#  'Maintain and prepare cash indent, cash report, cash position, and cash '
#  'planning\n'
#  'Responsibilities:\n'
#  ' Maintain Daily MIS in excel.\n'
#  ' Provide complete information about MIS & ATM.\n'
#  ' Maintain and prepare cash indent, cash report, cash position., cash '
#  'planning\n'
#  ' Co-ordinate with BANK CASH DEPARTMENT.\n'
#  ' Co-ordinate with custodians\n'
#  '.\n'
#  'DEGREE/ COURSE          YEAR of PASSING   GRADE          '
#  'INSTITUTE                              UNIVERSITY/ BOARD   PERCENTAGE\n'
#  'company - ANGEL BROKING\n'
#  'description - Reporting: Assistant Manager /   SR. Manger\n'
#  'Responsibilities:\n'
#  ' Handling team of 14 Quality assurance team members\n'
#  ' Maintain Daily MIS in excel of team productivity\n'
#  ' Maintain and prepare repots, adding comments on remark\n'
#  ' mailing client  for modification of given number\n'
#  ' Mailing reports to different branches\n'
#  ' Coordinating with RM\n'
#  ' Provide complete information about script to client')

# %%
df_count = df.groupby(["job_id", "cv_id"])["Model"].count().reset_index()

# %%
# one_model_tuple = df_count[df_count["Model"] < 2][["job_id", "cv_id"]].values
# one_model_df = df[df.apply(lambda row: (row["job_id"], row["cv_id"]) in one_model_tuple, axis=1)]

# %%
x = """{
  "job_description_analysis": {
    "technical_skills": [
      {"MS SQL Server installation, configuration, and administration": "essential"},
      {"Always on availability groups, log shipping, database mirroring, and clustering": "advantageous"},
      {"SQL server patching activity": "essential"},
      {"Performance tuning": "essential"}
    ],
    "soft_skills": ["Troubleshooting", "Communication"],
    "required_experience": [3],
    "education_qualifications": []
  },
  "resume_evaluation": {
    "original_scores": {
      "technical_skills": 85,
      "soft_skills": 90,
      "relevant_experience": 80,
      "qualifications": 0
    },
    "missing_skills": [
      {"Database performance monitoring and optimization": "essential"}
    ]
  },
  "deeper_analysis": {
    "inferred_experiences": ["Capacity planning for database growth"]
  },
  "recalibrated_scores": {
    "technical_skills": 90,
    "soft_skills": 95,
    "experience": 85,
    "education_qualifications": 0
  },
  "assessment": {
    "suitability": "yes",
    "strengths": ["Strong technical skills in MS SQL Server", "Experience with Always on availability groups"],
    "potential_concerns": ["Limited experience with database performance monitoring and optimization"],
    "missing_skills": [
      {"Database performance monitoring and optimization": "essential"}
    ]
  }
}"""
